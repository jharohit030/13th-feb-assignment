# %%
#Question 1:

Exception class is the super class of the all the exception , in the exception class it handles the all kind of runtime error occur in code.
It is the base class for all the exceptions act as a parent. 
In Python, we can define custom exceptions by creating a new class that is derived from the built-in Exception class.
Example:
    
class InvalidAgeException(Exception):
    "Raised when the input value is less than 18"
    pass

number = 18

try:
    input_num = int(input("Enter a number: "))
    if input_num < number:
        raise InvalidAgeException
    else:
        print("Eligible to Vote")
        
except InvalidAgeException:
    print("Exception occurred: Invalid Age")
# Out:
# Enter a number:  20
# Eligible to Vote

# %%
#Question 2:

import  inspect as ip

def find(cls, ind = 0):
    
    print('-'*ind, cls.__name__)
    
    for K in cls.__subclasses__():
        find(K, ind+3)
print("The Hierarchy for inbuilt exception is: ")
ip.getclasstree(ip.getmro(BaseException))
find(BaseException)
# Out:
# The Hierarchy for inbuilt exception is:
#  BaseException
# --- Exception
# ------ TypeError
# --------- FloatOperation
# --------- MultipartConversionError
# ------ StopAsyncIteration
# ------ StopIteration
# ------ ImportError
# --------- ModuleNotFoundError
# --------- ZipImportError
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# ------------ ConnectionAbortedError
# ------------ ConnectionRefusedError
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# --------- BlockingIOError
# --------- ChildProcessError
# --------- FileExistsError
# --------- FileNotFoundError
# --------- IsADirectoryError
# --------- NotADirectoryError
# --------- InterruptedError
# ------------ InterruptedSystemCall
# --------- PermissionError
# --------- ProcessLookupError
# --------- TimeoutError
# --------- UnsupportedOperation
# --------- itimer_error
# --------- herror
# --------- gaierror
# --------- SSLError
# ------------ SSLCertVerificationError
# ...

# %%
#Question 3:

This class is the base class for those built-in exceptions that are raised for various arithmetic errors such as :
1.ZeroDivisionError:
    
Example:
    
try:  
    a = 10/0  
    print (a)
except ZeroDivisionError:  
        print ("This statement is raising an arithmetic exception.")
else:  
    print ("Success.")
# Out:
# This statement is raising an arithmetic exception.

# %%
2. FloatingPointError:
    
A FloatingPointError is raised when a floating point operation fails. This exception is always defined, but can only be raised when Python is configured with the–with-fpectl option,

Example:
import math
  
print (math.exp(1000))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[7], line 8
#       1 # 2. FloatingPointError:
#       2
#       3 # A FloatingPointError is raised when a floating point operation fails. This exception is always defined, but can only be raised when Python is configured with the–with-fpectl option,
#       4
#       5 # Example:
#       6 import math
# ----> 8 print (math.exp(1000))
#
# OverflowError: math range error

# %%
#Question 4:

This is the base class for those exceptions that are raised when a key or index used on a mapping or sequence is invalid or not found. The exceptions raised are :
1. Index Error

try:
    a=[1,2,3]
    print(a[3])
except LookupError:
    print("Index out of bound error. ")
else:
    print("success")
# Out:
# Index out of bound error.

# %%
2. Key Error

emp_dict = {'name':'Rohit', 'ID':1}
try:
    emp_id = emp_dict['ID']
    print(emp_id)
    
    emp_role = emp_dict['Role']
    print(emp_role)
except KeyError as k:
    print("Key not found in employee directory: ", k)
# Out:
# 1
# Key not found in employee directory:  'Role'

# %%
#Question 5:

Python raises ModuleNotFoundError when a Python module is not able to be found. This exception catches a much narrow range of faults than the parent exception ImportError.

try:
    import rohit
except ImportError as e:
    rohit = None
    
def myfun():
    if rohit is None:
        raise ImportError(f"myfun() requires rohit, which is failed to import in program")

# %%
myfun()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 myfun()
#
# Cell In[11], line 12, in myfun()
#      10 def myfun():
#      11     if rohit is None:
# ---> 12         raise ImportError(f"myfun() requires rohit, which is failed to import in program")
#
# ImportError: myfun() requires rohit, which is failed to import in program

# %%
#Question 6:

# 1. use always a specific exception

try:
    10/0
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %%
#2. print always a proper message

try:
    10/0
except ZeroDivisionError as e:
    print("i am trying to handle a Zero Division error")
# Out:
# i am trying to handle a Zero Division error

# %%
#3. always try to log your error

import logging
logging.basicConfig(filename = 'error.log', level = logging.ERROR)
try:
    10/0
except ZeroDivisionError as e:
    logging.error("i am trying to handle a zerodivision error {}".format(e))

# %%
#4. always avoid to write a multiple exception handling

try:
    10/0
except FileNotFoundError as e:
        logging.error("i am handling file not found {}".format(e))
except AttributeError as e:
    print("I am trying to handle attribute error")
except ZeroDivisionError as e:
    print("i am trying to handle a Zero Division error")
# Out:
# i am trying to handle a Zero Division error

# %%
# 6.Document all the error
#cleanup all the resources


try:
    with open("test.txt", 'w') as f:
        f.write('this is my data to file')
except FileNotFoundError as e:
    logging.error("i am handling file not found {} ".format(e))
finally:
    f.close()
